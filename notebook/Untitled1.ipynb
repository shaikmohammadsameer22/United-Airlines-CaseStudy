# %%
import pandas as pd

# Full path with raw string
flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
                      parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local'])

# Quick check
print(flights.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 # Full path with raw string
# ----> 4 flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\raw\Flight Level Data UPDATED.csv',
#       5                       parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local'])
#       7 # Quick check
#       8 print(flights.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\seema\\United-Airlines-CaseStudy\\Data\\raw\\Flight Level Data UPDATED.csv'

# %%
import pandas as pd

# Full path with raw string
flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
                      parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local'])

# Quick check
print(flights.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 # Full path with raw string
# ----> 4 flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\raw\Flight Level Data UPDATED.csv',
#       5                       parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local'])
#       7 # Quick check
#       8 print(flights.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\seema\\United-Airlines-CaseStudy\\Data\\raw\\Flight Level Data UPDATED.csv'

# %%
import pandas as pd

# Full path with raw string
flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
                      parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local'])

# Quick check
print(flights.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 import pandas as pd
#       3 # Full path with raw string
# ----> 4 flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
#       5                       parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local'])
#       7 # Quick check
#       8 print(flights.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:161, in CParserWrapper.__init__(self, src, **kwds)
#     155         self._validate_usecols_names(
#     156             usecols,
#     157             self.names,  # type: ignore[has-type]
#     158         )
#     160 # error: Cannot determine type of 'names'
# --> 161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:243, in ParserBase._validate_parse_dates_presence(self, columns)
#     233 missing_cols = ", ".join(
#     234     sorted(
#     235         {
#    (...)
#     240     )
#     241 )
#     242 if missing_cols:
# --> 243     raise ValueError(
#     244         f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245     )
#     246 # Convert positions to actual column names
#     247 return [
#     248     col if (isinstance(col, str) or col in columns) else columns[col]
#     249     for col in cols_needed
#     250 ]
#
# ValueError: Missing column provided to 'parse_dates': 'actual_departure_datetime_local'

# %%
import pandas as pd

# Full path with raw string to the UPDATED folder file
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local']
)

# Quick check of the first few rows
print(flights.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       3 # Full path with raw string to the UPDATED folder file
# ----> 4 flights = pd.read_csv(
#       5     r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
#       6     parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local']
#       7 )
#       9 # Quick check of the first few rows
#      10 print(flights.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:161, in CParserWrapper.__init__(self, src, **kwds)
#     155         self._validate_usecols_names(
#     156             usecols,
#     157             self.names,  # type: ignore[has-type]
#     158         )
#     160 # error: Cannot determine type of 'names'
# --> 161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:243, in ParserBase._validate_parse_dates_presence(self, columns)
#     233 missing_cols = ", ".join(
#     234     sorted(
#     235         {
#    (...)
#     240     )
#     241 )
#     242 if missing_cols:
# --> 243     raise ValueError(
#     244         f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245     )
#     246 # Convert positions to actual column names
#     247 return [
#     248     col if (isinstance(col, str) or col in columns) else columns[col]
#     249     for col in cols_needed
#     250 ]
#
# ValueError: Missing column provided to 'parse_dates': 'actual_departure_datetime_local'

# %%
import pandas as pd

# Read CSV without parsing dates first
flights = pd.read_csv(r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv')

# Check column names
print(flights.columns)
# Out:
# Index(['company_id', 'flight_number', 'scheduled_departure_date_local',
#        'scheduled_departure_station_code', 'scheduled_arrival_station_code',
#        'scheduled_departure_datetime_local',
#        'scheduled_arrival_datetime_local', 'actual_departure_datetime_local -',
#        'actual_arrival_datetime_local - ', 'total_seats', 'fleet_type',
#        'carrier', 'scheduled_ground_time_minutes',
#        'actual_ground_time_minutes', 'minimum_turn_minutes', 'Unnamed: 15',
#        'Ectracted_time_scheduled_departure_time_local',
#        'Ectracted_time_actual_departure_time_local', 'diff of R1-Q1'],
#       dtype='object')

# %%
import pandas as pd

# Read only the necessary columns from the UPDATED CSV
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['company_id', 'flight_number', 'scheduled_departure_datetime_local', 'actual_departure_datetime_local -'],
    parse_dates=['scheduled_departure_datetime_local', 'actual_departure_datetime_local -']
)

# Quick check
print(flights.head())
# Out:
#   company_id  flight_number scheduled_departure_datetime_local  \
# 0         OO           4792          2025-08-04 17:57:00+00:00
# 1         UA              3          2025-08-03 18:05:00+00:00
# 2         UA              3          2025-08-10 18:20:00+00:00
# 3         OO           5790          2025-08-06 18:20:00+00:00
# 4         UA              3          2025-08-05 18:20:00+00:00
#
#   actual_departure_datetime_local -
# 0         2025-08-04 18:04:00+00:00
# 1         2025-08-03 18:27:00+00:00
# 2         2025-08-10 20:11:00+00:00
# 3         2025-08-06 20:05:00+00:00
# 4         2025-08-05 18:16:00+00:00

# %%
import pandas as pd

# Read only the required columns
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['flight_number', 'diff of R1-Q1']
)

# Sort by flight_number in ascending order
flights_sorted = flights.sort_values(by='flight_number', ascending=True)

# Quick preview
print(flights_sorted.head())
# Out:
#     flight_number  diff of R1-Q1
# 22              3           19.0
# 20              3            1.0
# 15              3           -4.0
# 14              3           -8.0
# 24              3           20.0

# %%
import pandas as pd

# Read only the required columns
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['flight_number', 'diff of R1-Q1']
)

# Sort by flight_number in ascending order
flights_sorted = flights.sort_values(by='flight_number', ascending=True)

# Display all rows
print(flights_sorted.to_string(index=False))  # index=False to hide the row numbers
# Out:
#  flight_number  diff of R1-Q1
#              3           19.0
#              3            1.0
#              3           -4.0
#              3           -8.0
#              3           20.0
#              3           -6.0
#              3           -4.0
#              3           10.0
#              3           60.0
#              3           -1.0
#              3           28.0
#              3           -4.0
#              3          111.0
#              3           22.0
#              3           25.0
#            118            1.0
#            118           -7.0
#            118            8.0
#            118            5.0
#            118           -4.0
#            118            0.0
#            118           74.0
#            118           -1.0
#            118            8.0
#            118          129.0
#            118           -5.0
#            118           -3.0
#            118            0.0
#            118           -6.0
#            118           -2.0
#            202           34.0
#            202           30.0
#            219           38.0
#            219            0.0
#            219           12.0
#            219          115.0
#            219           -6.0
#            219           -1.0
#            219            1.0
#            219           -4.0
#            219            9.0
#            219            6.0
#            219           -1.0
#            219          194.0
#            219           -1.0
#            219            6.0
#            219            0.0
#            224           -4.0
#            224           -1.0
#            224           39.0
#            224           11.0
#            224           39.0
#            224           -3.0
#            224           -5.0
#            224           -4.0
#            224            7.0
#            224           -1.0
#            224            4.0
#            224           11.0
#            224           -5.0
#            224           69.0
#            224          132.0
#            247           -2.0
#            247            0.0
#            247           -6.0
#            247           -4.0
#            247           -2.0
#            247           15.0
#            247           -5.0
#            247           16.0
#            247           -1.0
#            247           37.0
#            247           -2.0
#            247           -7.0
#            247           29.0
#            265           -4.0
#            265           -1.0
#            265           -1.0
#            265           18.0
#            265            0.0
#            265           -5.0
#            265           45.0
#            265           -3.0
#            265            3.0
#            265           99.0
#            265            0.0
#            265           -4.0
#            265           40.0
#            265           -7.0
#            265           64.0
#            275          215.0
#            275           10.0
#            275           21.0
#            275           -7.0
#            275           68.0
#            275           -3.0
#            275           -4.0
#            275            0.0
#            275          203.0
#            275           -2.0
#           1205           22.0
#           1205            2.0
#           1205           72.0
#           1205            8.0
#           1205           -1.0
#           1205           -7.0
#           1205           -6.0
#           1205           -4.0
#           1209           -4.0
#           1209           -5.0
#           1209           22.0
#           1209           32.0
#           1209           -5.0
#           1209            0.0
#           1209           32.0
#           1209          162.0
#           1209           -4.0
#           1209           -7.0
#           1209           -1.0
#           1209            2.0
#           1209           10.0
#           1209           72.0
#           1209           51.0
#           1215           -9.0
#           1215            7.0
#           1215          -13.0
#           1215           -7.0
#           1215           -2.0
#           1215          104.0
#           1215           26.0
#           1215           -9.0
#           1215           -4.0
#           1215           -1.0
#           1215           -5.0
#           1215        -1173.0
#           1215           -2.0
#           1215           39.0
#           1215            3.0
#           1224            2.0
#           1224           -7.0
#           1224            0.0
#           1224           -4.0
#           1224           -5.0
#           1224           22.0
#           1224           42.0
#           1224           41.0
#           1224           24.0
#           1224           -7.0
#           1224            0.0
#           1239            3.0
#           1239           -4.0
#           1239           -5.0
#           1239           28.0
#           1239            1.0
#           1239           25.0
#           1239           33.0
#           1239           -7.0
#           1239           -3.0
#           1239           13.0
#           1239           -8.0
#           1239            4.0
#           1239           46.0
#           1239           -2.0
#           1239           -6.0
#           1252           -3.0
#           1252           -4.0
#           1252           -1.0
#           1252          209.0
#           1252            0.0
#           1252           -3.0
#           1252            0.0
#           1252            5.0
#           1252           -4.0
#           1252            2.0
#           1252            2.0
#           1252            1.0
#           1252           -2.0
#           1252          152.0
# ...
#           5637            NaN
#           5637            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5643            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5646            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5652            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5668            NaN
#           5695            NaN
#           5695            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5699            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5712            NaN
#           5946            NaN
#           5946            NaN
#           5946            NaN
#           5946            NaN
#           5946            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5948            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5963            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5964            NaN
#           5968            NaN
#           5968            NaN
#           5968            NaN
#           5968            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5977            NaN
#           5980            NaN
#           5980            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5984            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5988            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           5999            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6002            NaN
#           6004            NaN
#           6004            NaN
#           6004            NaN
#           6004            NaN
#           6004            NaN
#           6004            NaN
#           6004            NaN

# %%
import pandas as pd

# Read only the required columns
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['flight_number', 'diff of R1-Q1']
)

# Calculate percentage of positive 'diff of R1-Q1' per flight
percentage_df = flights.groupby('flight_number').apply(
    lambda x: pd.Series({'positive_percentage': (x['diff of R1-Q1'] > 0).sum() / len(x) * 100})
).reset_index()

# Sort by flight_number in ascending order
percentage_df = percentage_df.sort_values(by='flight_number', ascending=True)

# Preview
print(percentage_df)
# Out:
#      flight_number  positive_percentage
# 0                3            60.000000
# 1              118            40.000000
# 2              202           100.000000
# 3              219            53.333333
# 4              224            53.333333
# ..             ...                  ...
# 619           5984             0.000000
# 620           5988             0.000000
# 621           5999             0.000000
# 622           6002             0.000000
# 623           6004             0.000000
#
# [624 rows x 2 columns]
# C:\Users\seema\AppData\Local\Temp\ipykernel_11676\3766547656.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percentage_df = flights.groupby('flight_number').apply(

# %%
import pandas as pd

# Read only the required columns
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['flight_number', 'diff of R1-Q1']
)

# Calculate percentage of positive 'diff of R1-Q1' per flight
percentage_df = flights.groupby('flight_number').apply(
    lambda x: pd.Series({'positive_percentage': (x['diff of R1-Q1'] >= 0).sum() / len(x) * 100})
).reset_index()

# Sort by flight_number in ascending order
percentage_df = percentage_df.sort_values(by='flight_number', ascending=True)

# Preview
print(percentage_df)
# Out:
#      flight_number  positive_percentage
# 0                3            60.000000
# 1              118            53.333333
# 2              202           100.000000
# 3              219            66.666667
# 4              224            53.333333
# ..             ...                  ...
# 619           5984             0.000000
# 620           5988             0.000000
# 621           5999             0.000000
# 622           6002             0.000000
# 623           6004             0.000000
#
# [624 rows x 2 columns]
# C:\Users\seema\AppData\Local\Temp\ipykernel_11676\3274095086.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percentage_df = flights.groupby('flight_number').apply(

# %%
import pandas as pd

# Read only the required columns
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['flight_number', 'diff of R1-Q1']
)

# Keep only rows where diff of R1-Q1 is positive
flights_positive = flights[flights['diff of R1-Q1'] > 0]

# Calculate percentage of positive 'diff of R1-Q1' per flight
percentage_df = flights_positive.groupby('flight_number').apply(
    lambda x: pd.Series({'positive_percentage': (x['diff of R1-Q1'] > 0).sum() / len(x) * 100})
).reset_index()

# Sort by flight_number in ascending order
percentage_df = percentage_df.sort_values(by='flight_number', ascending=True)

# Preview
print(percentage_df)
# Out:
#      flight_number  positive_percentage
# 0                3                100.0
# 1              118                100.0
# 2              202                100.0
# 3              219                100.0
# 4              224                100.0
# ..             ...                  ...
# 324           2683                100.0
# 325           2684                100.0
# 326           2691                100.0
# 327           2862                100.0
# 328           2865                100.0
#
# [329 rows x 2 columns]
# C:\Users\seema\AppData\Local\Temp\ipykernel_11676\2812104536.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percentage_df = flights_positive.groupby('flight_number').apply(

# %%
import pandas as pd

# Read only the required columns
flights = pd.read_csv(
    r'C:\Users\seema\United-Airlines-CaseStudy\Data\UPDATED\Flight Level Data UPDATED.csv',
    usecols=['flight_number', 'diff of R1-Q1']
)

# Calculate percentage of positive 'diff of R1-Q1' per flight using all rows
percentage_df = flights.groupby('flight_number').apply(
    lambda x: pd.Series({
        'positive_percentage': (x['diff of R1-Q1'] > 0).sum() / len(x) * 100
    })
).reset_index()

# Keep only flights with percentage > 0 (i.e., at least one positive diff)
percentage_df = percentage_df[percentage_df['positive_percentage'] > 0]

# Sort by flight_number in ascending order
percentage_df = percentage_df.sort_values(by='flight_number', ascending=True)

# Preview
print(percentage_df)
# Out:
#      flight_number  positive_percentage
# 0                3            60.000000
# 1              118            40.000000
# 2              202           100.000000
# 3              219            53.333333
# 4              224            53.333333
# ..             ...                  ...
# 326           2683            46.666667
# 327           2684            66.666667
# 328           2691            23.076923
# 329           2862            60.000000
# 330           2865            58.333333
#
# [329 rows x 2 columns]
# C:\Users\seema\AppData\Local\Temp\ipykernel_11676\781714710.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percentage_df = flights.groupby('flight_number').apply(
